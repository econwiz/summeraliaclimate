# %%
from funcs_support import get_params
import os
import glob

dir_list = get_params()
print(dir_list)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from funcs_support import get_params
#       2 import os
#       3 import glob
#
# File ~/summeraliaclimate/code/funcs_support.py:2
#       1 import xarray as xr
# ----> 2 import xagg as xa
#       3 import pandas as pd
#       4 import numpy as np
#
# ModuleNotFoundError: No module named 'xagg'

# %%
from funcs_support import get_params
import os
import glob

dir_list = get_params()
print(dir_list)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 from funcs_support import get_params
#       2 import os
#       3 import glob
#
# File ~/summeraliaclimate/code/funcs_support.py:2
#       1 import xarray as xr
# ----> 2 import xagg as xa
#       3 import pandas as pd
#       4 import numpy as np
#
# ModuleNotFoundError: No module named 'xagg'

# %%
pip install xagg
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Obtaining dependency information for xagg from https://files.pythonhosted.org/packages/b2/87/e144a9b753793f8439fd4dc1c3ccf7b8822a7fe76379a757cea3a836e81d/xagg-0.3.3.1-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for netcdf4 from https://files.pythonhosted.org/packages/18/c1/7e564dbd28228ba4a35a272bf53b9a2e8b0ba9ac06b2c84b57c03c84e87b/netCDF4-1.7.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
# ...
#   Obtaining dependency information for geopandas>=0.12.0 from https://files.pythonhosted.org/packages/be/82/79e02a0e5dd4aca81894842b9d6522624a40048a913c6384efb2987a4144/geopandas-1.1.0-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for shapely from https://files.pythonhosted.org/packages/a2/17/e09357274699c6e012bbb5a8ea14765a4d5860bb658df1931c9f90d53bd3/shapely-2.1.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
# ...

# %%
from funcs_support import get_params
import os
import glob

dir_list = get_params()
print(dir_list)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 from funcs_support import get_params
#       2 import os
#       3 import glob
#
# File ~/summeraliaclimate/code/funcs_support.py:2
#       1 import xarray as xr
# ----> 2 import xagg as xa
#       3 import pandas as pd
#       4 import numpy as np
#
# ModuleNotFoundError: No module named 'xagg'

# %%
from funcs_support import get_params
dir_list = get_params()
print(dir_list)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 from funcs_support import get_params
#       2 dir_list = get_params()
#       3 print(dir_list)
#
# File ~/summeraliaclimate/code/funcs_support.py:2
#       1 import xarray as xr
# ----> 2 import xagg as xa
#       3 import pandas as pd
#       4 import numpy as np
#
# ModuleNotFoundError: No module named 'xagg'

# %%
from funcs_support import get_params
dir_list = get_params()
print(dir_list)
# Out:
# /user/ab5405/.local/lib/python3.11/site-packages/pandas/core/arrays/masked.py:61: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (
# /user/ab5405/.local/lib/python3.11/site-packages/xagg/core.py:565: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   @njit
# ...

# %%
# Load file paths
from funcs_support import get_params, get_filepaths
dir_list = get_params()
df = get_filepaths(source_dir='proc')
print(df.head())

# Pick one dataset path
zarr_path = df['path'].iloc[0]
print(zarr_path)
# Out:
#          varname freq         model     exp        run      gwl proj_method  \
# 0  tasdmgfparams  day  IPSL-CM6A-LR  ssp245  r22i1p1f1  ALLGWLs         QDM
# 1  tasdmgfparams  day  IPSL-CM6A-LR  ssp245   r1i1p1f1  ALLGWLs         QDM
# 2  tasdmgfparams  day  IPSL-CM6A-LR  ssp245   r2i1p1f1  ALLGWLs         QDM
# 3  tasdmgfparams  day  IPSL-CM6A-LR  ssp245  r11i1p1f1  ALLGWLs         QDM
# 4  tasdmgfparams  day  IPSL-CM6A-LR  ssp245  r25i1p1f1  ALLGWLs         QDM
#
#   proj_base dwnscl_method dwnscl_target suffix filetype  \
# 0  ERA5-025         QPLAD        025deg  CONUS     zarr
# 1  ERA5-025         QPLAD        025deg  CONUS     zarr
# 2  ERA5-025         QPLAD        025deg  CONUS     zarr
# 3  ERA5-025         QPLAD        025deg  CONUS     zarr
# 4  ERA5-025         QPLAD        025deg  CONUS     zarr
#
#                                                 path
# 0  /user/ab5405/summeraliaclimate/data/climate_pr...
# 1  /user/ab5405/summeraliaclimate/data/climate_pr...
# ...

# %%
from funcs_support import get_params,get_filepaths

df = get_filepaths(source_dir = 'proc')

print(df)
# Out:
#           varname freq         model     exp        run      gwl proj_method  \
# 0   tasdmgfparams  day  IPSL-CM6A-LR  ssp245  r22i1p1f1  ALLGWLs         QDM
# 1   tasdmgfparams  day  IPSL-CM6A-LR  ssp245   r1i1p1f1  ALLGWLs         QDM
# 2   tasdmgfparams  day  IPSL-CM6A-LR  ssp245   r2i1p1f1  ALLGWLs         QDM
# 3   tasdmgfparams  day  IPSL-CM6A-LR  ssp245  r11i1p1f1  ALLGWLs         QDM
# 4   tasdmgfparams  day  IPSL-CM6A-LR  ssp245  r25i1p1f1  ALLGWLs         QDM
# ..            ...  ...           ...     ...        ...      ...         ...
# 5   tasdmgfparams  day    MRI-ESM2-0  ssp370   r3i1p1f1  ALLGWLs         QDM
# 6   tasdmgfparams  day    MRI-ESM2-0  ssp370   r2i1p1f1  ALLGWLs         QDM
# 7   tasdmgfparams  day    MRI-ESM2-0  ssp585   r1i2p1f1  ALLGWLs         QDM
# 8   tasdmgfparams  day    MRI-ESM2-0  ssp245   r2i1p1f1  ALLGWLs         QDM
# 9   tasdmgfparams  day    MRI-ESM2-0  ssp245   r4i1p1f1  ALLGWLs         QDM
#
# ...

# %%
# !pip install zarr

# %%
pip install --upgrade "xarray[io]"
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Obtaining dependency information for h5netcdf from https://files.pythonhosted.org/packages/b2/fc/e73747f3dd31906bfbb78c76069f67d91525fefa28492a1f949cbb4a3c7f/h5netcdf-1.6.1-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for zarr from https://files.pythonhosted.org/packages/00/3b/e20bdf84088c11f2c396d034506cbffadd53e024111c1aa4585c2aba1523/zarr-3.0.8-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for pooch from https://files.pythonhosted.org/packages/a8/87/77cc11c7a9ea9fd05503def69e3d18605852cd0d4b0d3b8f15bbeb3ef1d1/pooch-1.8.2-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for donfig>=0.8 from https://files.pythonhosted.org/packages/0c/d5/c5db1ea3394c6e1732fb3286b3bd878b59507a8f77d32a2cebda7d7b7cd4/donfig-0.8.1.post1-py3-none-any.whl.metadata
# ...

# %%
b
# Out:
# /user/ab5405/.local/lib/python3.11/site-packages/pandas/core/arrays/masked.py:61: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 import xarray as xr
# ----> 2 ds = xr.open_zarr(zarr_path, consolidated=True)
#       3 ds
#
# NameError: name 'zarr_path' is not defined

# %%
zarr_path = df['path'].iloc[0]
print(zarr_path)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 zarr_path = df['path'].iloc[0]
#       2 print(zarr_path)
#
# NameError: name 'df' is not defined

# %%
# Load file paths
from funcs_support import get_params, get_filepaths
dir_list = get_params()
df = get_filepaths(source_dir='proc')
print(df.head())

# Pick one dataset path
zarr_path = df['path'].iloc[0]
print(zarr_path)
# Out:
#          varname freq         model     exp        run      gwl proj_method  \
# 0  tasdmgfparams  day  IPSL-CM6A-LR  ssp245  r22i1p1f1  ALLGWLs         QDM
# 1  tasdmgfparams  day  IPSL-CM6A-LR  ssp245   r1i1p1f1  ALLGWLs         QDM
# 2  tasdmgfparams  day  IPSL-CM6A-LR  ssp245   r2i1p1f1  ALLGWLs         QDM
# 3  tasdmgfparams  day  IPSL-CM6A-LR  ssp245  r11i1p1f1  ALLGWLs         QDM
# 4  tasdmgfparams  day  IPSL-CM6A-LR  ssp245  r25i1p1f1  ALLGWLs         QDM
#
#   proj_base dwnscl_method dwnscl_target suffix filetype  \
# 0  ERA5-025         QPLAD        025deg  CONUS     zarr
# 1  ERA5-025         QPLAD        025deg  CONUS     zarr
# 2  ERA5-025         QPLAD        025deg  CONUS     zarr
# 3  ERA5-025         QPLAD        025deg  CONUS     zarr
# 4  ERA5-025         QPLAD        025deg  CONUS     zarr
#
#                                                 path
# 0  /user/ab5405/summeraliaclimate/data/climate_pr...
# 1  /user/ab5405/summeraliaclimate/data/climate_pr...
# ...

# %%
zarr_path = df['path'].iloc[0]
print(zarr_path)
# Out:
# /user/ab5405/summeraliaclimate/data/climate_proc/IPSL-CM6A-LR/tasdmgfparams_day_IPSL-CM6A-LR_ssp245_r22i1p1f1_ALLGWLS_projQDM-baseERA5-025_dwnsclQPLAD-target025deg_CONUS.zarr

# %%
ds = xr.open_zarr(zarr_path, consolidated = False)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 ds = xr.open_zarr(zarr_path, consolidated = False)
#
# File ~/.local/lib/python3.11/site-packages/xarray/backends/zarr.py:1505, in open_zarr(store, group, synchronizer, chunks, decode_cf, mask_and_scale, decode_times, concat_characters, decode_coords, drop_variables, consolidated, overwrite_encoded_chunks, chunk_store, storage_options, decode_timedelta, use_cftime, zarr_version, zarr_format, use_zarr_fill_value_as_mask, chunked_array_type, from_array_kwargs, **kwargs)
#    1491     raise TypeError(
#    1492         "open_zarr() got unexpected keyword arguments " + ",".join(kwargs.keys())
#    1493     )
#    1495 backend_kwargs = {
#    1496     "synchronizer": synchronizer,
#    1497     "consolidated": consolidated,
#    (...)
#    1502     "zarr_format": zarr_format,
#    1503 }
# ...

# %%
import zarr
z = zarr.open("/user/ab5405/summeraliaclimate/data/climate_proc/IPSL-CM6A-LR/tasdmgfparams_day_IPSL-CM6A-LR_ssp245_r22i1p1f1_ALLGWLS_projQDM-baseERA5-025_dwnsclQPLAD-target025deg_CONUS.zarr/bins_behrer", mode='r')
print(z.shape, z.dtype)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[10], line 2
#       1 import zarr
# ----> 2 z = zarr.open("/user/ab5405/summeraliaclimate/data/climate_proc/IPSL-CM6A-LR/tasdmgfparams_day_IPSL-CM6A-LR_ssp245_r22i1p1f1_ALLGWLS_projQDM-baseERA5-025_dwnsclQPLAD-target025deg_CONUS.zarr/bins_behrer", mode='r')
#       3 print(z.shape, z.dtype)
#
# File ~/.local/lib/python3.11/site-packages/zarr/_compat.py:43, in _deprecate_positional_args.<locals>._inner_deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      41 extra_args = len(args) - len(all_args)
#      42 if extra_args <= 0:
# ---> 43     return f(*args, **kwargs)
#      45 # extra_args > 0
#      46 args_msg = [
#      47     f"{name}={arg}"
#      48     for name, arg in zip(kwonly_args[:extra_args], args[-extra_args:], strict=False)
#      49 ]
#
# ...

# %%
zarr_path = df['path'].iloc[0]
print(zarr_path)
ds = xr.open_zarr(zarr_path)
ds
# Out:
# /user/ab5405/summeraliaclimate/data/climate_proc/IPSL-CM6A-LR/tasdmgfparams_day_IPSL-CM6A-LR_ssp245_r22i1p1f1_ALLGWLS_projQDM-baseERA5-025_dwnsclQPLAD-target025deg_CONUS.zarr
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[13], line 3
#       1 zarr_path = df['path'].iloc[0]
#       2 print(zarr_path)
# ----> 3 ds = xr.open_zarr(zarr_path)
#       4 ds
#
# File ~/.local/lib/python3.11/site-packages/xarray/backends/zarr.py:1505, in open_zarr(store, group, synchronizer, chunks, decode_cf, mask_and_scale, decode_times, concat_characters, decode_coords, drop_variables, consolidated, overwrite_encoded_chunks, chunk_store, storage_options, decode_timedelta, use_cftime, zarr_version, zarr_format, use_zarr_fill_value_as_mask, chunked_array_type, from_array_kwargs, **kwargs)
#    1491     raise TypeError(
# ...

# %%
import os

for path in df['path']:
    zgroup_file = os.path.join(path, '.zgroup')
    if not os.path.exists(zgroup_file):
        print("Missing .zgroup in:", path)
    else:
        print("OK:", path)
# Out:
# ❌ Missing .zgroup in: /user/ab5405/summeraliaclimate/data/climate_proc/IPSL-CM6A-LR/tasdmgfparams_day_IPSL-CM6A-LR_ssp245_r22i1p1f1_ALLGWLS_projQDM-baseERA5-025_dwnsclQPLAD-target025deg_CONUS.zarr
# ❌ Missing .zgroup in: /user/ab5405/summeraliaclimate/data/climate_proc/IPSL-CM6A-LR/tasdmgfparams_day_IPSL-CM6A-LR_ssp245_r1i1p1f1_ALLGWLS_projQDM-baseERA5-025_dwnsclQPLAD-target025deg_CONUS.zarr
# ❌ Missing .zgroup in: /user/ab5405/summeraliaclimate/data/climate_proc/IPSL-CM6A-LR/tasdmgfparams_day_IPSL-CM6A-LR_ssp245_r2i1p1f1_ALLGWLS_projQDM-baseERA5-025_dwnsclQPLAD-target025deg_CONUS.zarr
# ❌ Missing .zgroup in: /user/ab5405/summeraliaclimate/data/climate_proc/IPSL-CM6A-LR/tasdmgfparams_day_IPSL-CM6A-LR_ssp245_r11i1p1f1_ALLGWLS_projQDM-baseERA5-025_dwnsclQPLAD-target025deg_CONUS.zarr
# ❌ Missing .zgroup in: /user/ab5405/summeraliaclimate/data/climate_proc/IPSL-CM6A-LR/tasdmgfparams_day_IPSL-CM6A-LR_ssp245_r25i1p1f1_ALLGWLS_projQDM-baseERA5-025_dwnsclQPLAD-target025deg_CONUS.zarr
# ...

# %%
ds = xr.open_mfdataset(zarr_path, engine="zarr")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 ds = xr.open_mfdataset(zarr_path, engine="zarr")
#
# File ~/.local/lib/python3.11/site-packages/xarray/backends/api.py:1635, in open_mfdataset(paths, chunks, concat_dim, compat, preprocess, engine, data_vars, coords, combine, parallel, join, attrs_file, combine_attrs, **kwargs)
#    1632     open_ = open_dataset
#    1633     getattr_ = getattr
# -> 1635 datasets = [open_(p, **open_kwargs) for p in paths1d]
#    1636 closers = [getattr_(ds, "_close") for ds in datasets]
#    1637 if preprocess is not None:
#
# File ~/.local/lib/python3.11/site-packages/xarray/backends/api.py:1635, in <listcomp>(.0)
#    1632     open_ = open_dataset
#    1633     getattr_ = getattr
# -> 1635 datasets = [open_(p, **open_kwargs) for p in paths1d]
#    1636 closers = [getattr_(ds, "_close") for ds in datasets]
# ...

# %%
# Load file paths
from funcs_support import get_params, get_filepaths
dir_list = get_params()
df = get_filepaths(source_dir='extracted')
print(df.head())
bb
# Pick one dataset path
zarr_path = df['path'].iloc[0]
print(zarr_path)
# Out:
# /user/ab5405/.local/lib/python3.11/site-packages/pandas/core/arrays/masked.py:61: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (
# Empty DataFrame
# Columns: []
# Index: []
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[1], line 8
#       5 print(df.head())
#       7 # Pick one dataset path
# ----> 8 zarr_path = df['path'].iloc[0]
#       9 print(zarr_path)
#
# File ~/.local/lib/python3.11/site-packages/pandas/core/frame.py:4107, in DataFrame.__getitem__(self, key)
#    4105 if self.columns.nlevels > 1:
#    4106     return self._getitem_multilevel(key)
# -> 4107 indexer = self.columns.get_loc(key)
#    4108 if is_integer(indexer):
#    4109     indexer = [indexer]
#
# ...

# %%
[get for get in dir_list if 'extracted' in get]
# Out:
# ['extracted']

# %%
# Load file paths
from funcs_support import get_params, get_filepaths
dir_list = get_params()
df = get_filepaths(source_dir='extracted')
print(df.head())

# Pick one dataset path
zarr_path = df['path'].iloc[0]
print(zarr_path)
# Out:
#          varname freq          model     exp        run      gwl proj_method  \
# 0  tasdmgfparams  day  ACCESS-ESM1-5  ssp245  r10i1p1f1  ALLGWLs         QDM
#
#   proj_base dwnscl_method dwnscl_target suffix filetype  \
# 0  ERA5-025         QPLAD        025deg  CONUS     zarr
#
#                                                 path
# 0  /user/ab5405/summeraliaclimate/data/ACCESS-ESM...
# /user/ab5405/summeraliaclimate/data/ACCESS-ESM1-5/tasdmgfparams_day_ACCESS-ESM1-5_ssp245_r10i1p1f1_ALLGWLS_projQDM-baseERA5-025_dwnsclQPLAD-target025deg_CONUS.zarr

# %%
print(ds)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 print(ds)
#
# NameError: name 'ds' is not defined

# %%
import xarray as xr

zarr_path = "/user/ab5405/summeraliaclimate/data/ACCESS-ESM1-5/tasdmgfparams_day_ACCESS-ESM1-5_ssp245_r10i1p1f1_ALLGWLS_projQDM-baseERA5-025_dwnsclQPLAD-target025deg_CONUS.zarr"
ds = xr.open_zarr(zarr_path, consolidated=False)
ds
# Out:
# <xarray.Dataset> Size: 28MB
# Dimensions:          (lat: 120, bnds: 2, bin_f: 22, lon: 268, gwl: 5)
# Coordinates:
#   * lat              (lat) float64 960B 23.12 23.38 23.62 ... 52.38 52.62 52.88
#   * bnds             (bnds) int64 16B 0 1
#   * bin_f            (bin_f) float64 176B 254.0 256.8 259.5 ... 309.5 312.3
#   * gwl              (gwl) float64 40B 0.61 1.0 1.5 2.0 2.5
#   * lon              (lon) float64 2kB -126.9 -126.6 -126.4 ... -60.38 -60.12
# Data variables:
#     bin_bnds_behrer  (bin_f, bnds) float64 352B dask.array<chunksize=(22, 2), meta=np.ndarray>
#     bins_behrer      (lat, lon, gwl, bin_f) float64 28MB dask.array<chunksize=(120, 268, 1, 22), meta=np.ndarray>
# Attributes:
#     DESCRIPTION:  tasdmgfparams files, subset to CONUS and just F bins
#     SOURCE:       deela transfer_for_alia.ipynb

# %%
ds.data_vars
ds.dims
ds.coords
ds.attrs
# Out:
# {'DESCRIPTION': 'tasdmgfparams files, subset to CONUS and just F bins',
#  'SOURCE': 'deela transfer_for_alia.ipynb'}

# %%
ds['bin_f']
# Out:
# <xarray.DataArray 'bin_f' (bin_f: 22)> Size: 176B
# array([253.983333, 256.761111, 259.538889, 262.316667, 265.094444, 267.872222,
#        270.65    , 273.427778, 276.205556, 278.983333, 281.761111, 284.538889,
#        287.316667, 290.094444, 292.872222, 295.65    , 298.427778, 301.205556,
#        303.983333, 306.761111, 309.538889, 312.316667])
# Coordinates:
#   * bin_f    (bin_f) float64 176B 254.0 256.8 259.5 262.3 ... 306.8 309.5 312.3

# %%
list(ds.data_vars)
# Out:
# ['bin_bnds_behrer', 'bins_behrer']

# %%
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import cartopy.feature as cfeature

# Select bins and GWLs
gwl_25 = ds['bins_behrer'].sel(gwl=2.5, bin_f=ds['bin_f'][0])
gwl_10 = ds['bins_behrer'].sel(gwl=1.0, bin_f=ds['bin_f'][0])

# Compute change
change = gwl_25 - gwl_10

# Plot
fig = plt.figure(figsize=(10, 6))
ax = plt.axes(projection=ccrs.PlateCarree())
pc = ax.pcolormesh(ds['lon'], ds['lat'], change, transform=ccrs.PlateCarree(), shading='auto')

ax.coastlines()
ax.add_feature(cfeature.BORDERS, linestyle=':')
ax.set_title(f"Δ Days in Bin {ds['bin_f'][0].values:.1f}K: GWL 2.5°C - 1.0°C")
plt.colorbar(pc, ax=ax, label='Δ Days')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 2
#       1 import matplotlib.pyplot as plt
# ----> 2 import cartopy.crs as ccrs
#       3 import cartopy.feature as cfeature
#       5 # Select bins and GWLs
#
# ModuleNotFoundError: No module named 'cartopy'

# %%
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import cartopy.feature as cfeature

import xarray as xr

zarr_path = "/user/ab5405/summeraliaclimate/data/ACCESS-ESM1-5/tasdmgfparams_day_ACCESS-ESM1-5_ssp245_r10i1p1f1_ALLGWLS_projQDM-baseERA5-025_dwnsclQPLAD-target025deg_CONUS.zarr"
ds = xr.open_zarr(zarr_path, consolidated=False)
print(ds)

# Select bins and GWL
gwl_25 = ds['bins_behrer'].sel(gwl=2.5, bin_f=ds['bin_f'][6])
gwl_10 = ds['bins_behrer'].sel(gwl=1.0, bin_f=ds['bin_f'][6])

# Compute change
change = gwl_25 - gwl_10

# Plot
fig = plt.figure(figsize=(10, 6))
ax = plt.axes(projection=ccrs.PlateCarree())
pc = ax.pcolormesh(ds['lon'], ds['lat'], change, transform=ccrs.PlateCarree(), shading='auto')

ax.coastlines()
ax.add_feature(cfeature.BORDERS, linestyle=':')
ax.set_title(f"Δ Days in Bin {ds['bin_f'][6].values:.1f}K: GWL 2.5°C - 1.0°C")
plt.colorbar(pc, ax=ax, label='Δ Days')
plt.show()
# Out:
# <xarray.Dataset> Size: 28MB
# Dimensions:          (lat: 120, lon: 268, gwl: 5, bin_f: 22, bnds: 2)
# Coordinates:
#   * lat              (lat) float64 960B 23.12 23.38 23.62 ... 52.38 52.62 52.88
#   * bin_f            (bin_f) float64 176B 254.0 256.8 259.5 ... 309.5 312.3
#   * bnds             (bnds) int64 16B 0 1
#   * lon              (lon) float64 2kB -126.9 -126.6 -126.4 ... -60.38 -60.12
#   * gwl              (gwl) float64 40B 0.61 1.0 1.5 2.0 2.5
# Data variables:
#     bins_behrer      (lat, lon, gwl, bin_f) float64 28MB dask.array<chunksize=(120, 268, 1, 22), meta=np.ndarray>
#     bin_bnds_behrer  (bin_f, bnds) float64 352B dask.array<chunksize=(22, 2), meta=np.ndarray>
# Attributes:
#     DESCRIPTION:  tasdmgfparams files, subset to CONUS and just F bins
#     SOURCE:       deela transfer_for_alia.ipynb

# %%
print(ds.dims)
# Out:
# FrozenMappingWarningOnValuesAccess({'lat': 120, 'lon': 268, 'gwl': 5, 'bin_f': 22, 'bnds': 2})

# %%
print(ds['bin_f'])               # See variable definition
print(ds['bin_f'].values)       # Print all values
print(ds['bins_behrer'].dims)   # See which dimensions use `bin_f`
# Out:
# <xarray.DataArray 'bin_f' (bin_f: 22)> Size: 176B
# array([253.983333, 256.761111, 259.538889, 262.316667, 265.094444, 267.872222,
#        270.65    , 273.427778, 276.205556, 278.983333, 281.761111, 284.538889,
#        287.316667, 290.094444, 292.872222, 295.65    , 298.427778, 301.205556,
#        303.983333, 306.761111, 309.538889, 312.316667])
# Coordinates:
#   * bin_f    (bin_f) float64 176B 254.0 256.8 259.5 262.3 ... 306.8 309.5 312.3
# [253.98333333 256.76111111 259.53888889 262.31666667 265.09444444
#  267.87222222 270.65       273.42777778 276.20555556 278.98333333
#  281.76111111 284.53888889 287.31666667 290.09444444 292.87222222
#  295.65       298.42777778 301.20555556 303.98333333 306.76111111
#  309.53888889 312.31666667]
# ('lat', 'lon', 'gwl', 'bin_f')
